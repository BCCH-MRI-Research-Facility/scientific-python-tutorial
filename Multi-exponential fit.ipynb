# %%
# %matplotlib notebook

# %%
def t2decay(t,A,B,T2myelin,T2ieh2O):
    return A*np.exp(-t/T2myelin) + B*np.exp(-t/T2ieh2O)

# %%
xdata = np.linspace(0,32,32)

# %%
ydataraw = t2decay(xdata,10,90,15,45)

# %%
ydata = ydataraw + np.random.random(32)

# %%
f,ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax.scatter(xdata,ydata)

# %%
from scipy.optimize import curve_fit

# %%
popt,pcov = curve_fit(t2decay,xdata,ydata,bounds=([0,0,10,40],[np.inf,np.inf,20,50]),p0=[10,90,15,45])

# %%
popt
# Out:
# array([ 17.3114731 ,  83.58528094,  18.30128081,  47.77423181])

# %%
pcov
# Out:
# array([[ 1120.85780156, -1123.75979452,   471.58629123,   412.1478504 ],
#        [-1123.75979452,  1126.6871315 ,  -472.88858197,  -413.18527186],
#        [  471.58629123,  -472.88858197,   199.10137205,   173.05536253],
#        [  412.1478504 ,  -413.18527186,   173.05536253,   151.75462826]])

# %%
fitdata = t2decay(xdata,*popt)

# %%
plt.scatter(xdata,fitdata)

# %%
popt2,pcov2 = curve_fit(t2decay,xdata,ydata)

# %%
fitdata_nobounds = t2decay(xdata,*popt)

# %%
plt.scatter(xdata,fitdata_nobounds)
